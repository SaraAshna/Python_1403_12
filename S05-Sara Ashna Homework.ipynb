# %% [markdown]
# <p dir="rtl"> برنامه ای بنویسید که 2 لیست بگیرد و مقادیر غیر مشترک لیست ها را در یک لیست جداگانه ای خروجی دهد.

# %%
l1 = [1,2,3,5,7,4502,9,11,13,13,45]
l2 = [2,4,7,8,10,12,13]
result = []
for i in l1:
    if i not in l2: 
        result.append(i)
for n in l2:
    if n not in l1:
        result.append(n)
print (result)
# Out:
# [1, 3, 5, 4502, 9, 11, 45, 4, 8, 10, 12]

# %%
l1 = [1,2,3,5,7,4502,9,11,13,13,45]
l2 = [2,4,7,8,10,12,13]
list(set(l1)-set(l2).union(set(l2)-set(l1)))
# Out:
# [1, 3, 5, 9, 11, 45, 4502]

# %% [markdown]
# <p dir="rtl"> . برنامه ای بنویسید که یک مقدار لیست را گرفته و تعیین کند که آیا مقادیر درون آن به ترتیب صعودی مرتب شده اند یا نه؟

# %%
thislist = [0,1,7,-9,11,12,12,13,45]
for i in range(len(thislist)-1):
    if thislist[i]> thislist[i+1]:
        print('false')
        break

else:
    print('True')
# Out:
# false

# %%
thislist = [0,1,7,-9,11,12,12,13,45]
sorted(thislist)
sorted(thislist)==thislist
# Out:
# False

# %%
flag = True #assuming the condisitn is ok and the list is ascending 
pr =  l1[0]  #previous item 
for i in l1[1:]:
    if i <= pr:
        flag = False
        break
    pr = i

flag
# Out:
# False

# %%
l1 = [1,2,3,5,7,4502,9,11,13,13,45]
flag = True #assuming the condisitn is ok and the list is ascending 
l1 = sorted(l1)
print(l1)
pr =  l1[0]  #previous item 
for i in l1[1:]:
    if i < pr:
        flag = False
        break
    pr = i

flag
# Out:
# [1, 2, 3, 5, 7, 9, 11, 13, 13, 45, 4502]
# True

# %% [markdown]
# <p dir="rtl"> لیستی به طول ۱۰۰ آیتم ایجاد کنید برای هر آیتم لیست بصورت رندم یکی رشته های زیر را انتخاب کنید (راهنمایی : برای این هدف می تونید از کتابخانه random و تابع choice استفاده کنید) _ آیتم های انتخابی: hello, yello, mello, hallo

# %%
import random
r = [random.choice(["hello", "yello", "mello", "hallo"]) for _ in range(100)]
r
# Out:
# ['yello',
#  'hello',
#  'hello',
#  'hello',
#  'hello',
#  'hallo',
#  'hallo',
#  'yello',
#  'hello',
#  'hello',
#  'hello',
#  'hallo',
#  'hello',
#  'mello',
#  'hello',
#  'hello',
#  'yello',
#  'mello',
#  'hello',
#  'hello',
#  'hello',
#  'yello',
#  'hello',
#  'hello',
#  'mello',
#  'hallo',
#  'hello',
#  'hello',
#  'hello',
#  'hello',
#  'mello',
#  'hallo',
#  'hello',
#  'hello',
#  'mello',
#  'yello',
#  'hallo',
#  'hello',
#  'mello',
#  'mello',
#  'hello',
#  'hallo',
#  'mello',
#  'hallo',
#  'hallo',
#  'yello',
#  'mello',
#  'mello',
#  'mello',
#  'yello',
#  'mello',
#  'hello',
#  'yello',
#  'hallo',
#  'hallo',
#  'hallo',
#  'hallo',
#  'mello',
#  'mello',
#  'yello',
#  'hallo',
#  'hello',
#  'yello',
#  'mello',
#  'hallo',
#  'hallo',
#  'mello',
#  'hallo',
#  'mello',
#  'mello',
#  'yello',
#  'hello',
#  'yello',
#  'yello',
#  'mello',
#  'hello',
#  'yello',
#  'yello',
#  'yello',
#  'mello',
#  'hallo',
#  'hello',
#  'yello',
# ...

# %%
import random
s = ["hello", "yello", "mello", "hallo"]
list_1 = []
for i in range(100):
    list_1.append(random.choice(s))
print(list_1)
# Out:
# ['mello', 'mello', 'mello', 'hello', 'yello', 'hello', 'hello', 'yello', 'mello', 'hello', 'hallo', 'hallo', 'hallo', 'hallo', 'yello', 'yello', 'mello', 'yello', 'yello', 'yello', 'hello', 'hello', 'yello', 'yello', 'mello', 'hallo', 'hallo', 'mello', 'yello', 'yello', 'yello', 'yello', 'yello', 'mello', 'hello', 'hallo', 'hallo', 'yello', 'hello', 'hello', 'yello', 'yello', 'yello', 'hallo', 'yello', 'hello', 'mello', 'hello', 'yello', 'yello', 'mello', 'mello', 'yello', 'hallo', 'hello', 'yello', 'hallo', 'hallo', 'yello', 'hello', 'hello', 'hallo', 'yello', 'mello', 'hello', 'mello', 'hello', 'hallo', 'yello', 'hello', 'yello', 'hello', 'yello', 'hallo', 'hallo', 'hello', 'hello', 'yello', 'yello', 'yello', 'mello', 'hallo', 'hallo', 'hello', 'mello', 'yello', 'hello', 'mello', 'yello', 'hello', 'hello', 'hallo', 'hallo', 'hello', 'mello', 'mello', 'hello', 'mello', 'hallo', 'yello']

# %% [markdown]
# <p dir="rtl">در لیست تولید شده تمرین قبل آیتم های دارای غلط املایی را حذف کنید. (یعنی هر آیتمی که hello نیست)

# %%
#bug
import random
r = [random.choice(["hello", "yello", "mello", "hallo"]) for _ in range(100)]
for item in r: 
    if item != 'hello':
        result.append(r)  
    #in this case we will encounter bug as we are are changing the list within the loop 
print(result)
# Out:
# [1, 3, 5, 4502, 9, 11, 45, 4, 8, 10, 12, ['hello', 'yello', 'hallo', 'hello', 'yello', 'yello', 'hello', 'mello', 'hello', 'yello', 'yello', 'hallo', 'hello', 'mello', 'hello', 'hello', 'mello', 'hallo', 'mello', 'yello', 'hello', 'hallo', 'yello', 'hello', 'hallo', 'hello', 'yello', 'yello', 'mello', 'hello', 'hallo', 'mello', 'yello', 'yello', 'hallo', 'hello', 'hallo', 'yello', 'yello', 'mello', 'mello', 'yello', 'hallo', 'yello', 'mello', 'hello', 'hallo', 'hallo', 'mello', 'mello', 'mello', 'hello', 'mello', 'hallo', 'yello', 'mello', 'yello', 'yello', 'yello', 'hallo', 'hallo', 'mello', 'hallo', 'mello', 'hello', 'hallo', 'hallo', 'hallo', 'mello', 'mello', 'hallo', 'yello', 'yello', 'mello', 'mello', 'hello', 'mello', 'hello', 'hallo', 'hello', 'yello', 'yello', 'hallo', 'mello', 'hello', 'hello', 'hallo', 'yello', 'hallo', 'mello', 'mello', 'yello', 'hello', 'mello', 'mello', 'yello', 'yello', 'hello', 'hallo', 'hello'], ['hello', 'yello', 'hallo', 'hello', 'yello', 'yello', 
# ...

# %%
import random
s = ["hello", "yello", "mello", "hallo"]
list_1 = []
for i in range(100):
    choice = random.choice(s)
    if choice == 'hello':
        list_1.append(choice)
print(list_1)
# Out:
# ['hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello', 'hello']

# %% [markdown]
# <p dir="rtl">    دو لیست زیر را در نظر بگیرید لیست اول شامل اقلام مورد نیاز برای خرید و لیست دوم شامل مقدار مورد نیاز می باشد.
# list_1=[milk,suger,butter,yogurt,cheese]
#
#        list_2 =  [5,2,10,1,3]
#
# <p dir="rtl">    برنامه ای بنویسید که این دو لیست را در یک دیکشنری ادغام کند آیتم های لیست اول کلید و آیتم های لیست دوم مقادیر متناظر باشد

# %%
list_1=["milk","suger","butter","yogurt","cheese"]
list_2 =  [5,2,10,1,3]
result = {}
x = 0
for i in list_2:
    result.setdefault(list_1[x],i) 
    x +=1
result
# Out:
# {'milk': 5, 'suger': 2, 'butter': 10, 'yogurt': 1, 'cheese': 3}

# %%
list_1=["milk","suger","butter","yogurt","cheese"]
list_2 =  [5,2,10,1,3]
dict(zip(list_1,list_2))
# Out:
# {'milk': 5, 'suger': 2, 'butter': 10, 'yogurt': 1, 'cheese': 3}

# %%
d = {}
c = 0
for i in list_1:
    d[i] = list_2[c]
    c +=1
d
# Out:
# {'milk': 5, 'suger': 2, 'butter': 10, 'yogurt': 1, 'cheese': 3}

# %%
for i, item in enumerate(list_1):
    print(i,item)

#enumerate(a) provides both the index (i) and the element (name) during iteration.
# Out:
# 0 milk
# 1 suger
# 2 butter
# 3 yogurt
# 4 cheese

# %%
#enumerate:
به هر ایتم، ایندکس میدهد

a = ["Geeks", "for", "Geeks"]
 
# Iterating list using enumerate to get both index and element
for i, name in enumerate(a):
    print(f"Index {i}: {name}")

# Converting to a list of tuples
print(list(enumerate(a)))
# Out:
# Index 0: Geeks
# Index 1: for
# Index 2: Geeks
# [(0, 'Geeks'), (1, 'for'), (2, 'Geeks')]

# %%
d = {}
for i,item in enumerate(list_1):
    d[item] = list_2[i]
d
# Out:
# {'milk': 5, 'suger': 2, 'butter': 10, 'yogurt': 1, 'cheese': 3}

# %%
for i,item in enumerate(d):
    print(i,item)
# Out:
# 0 milk
# 1 suger
# 2 butter
# 3 yogurt
# 4 cheese

# %% [markdown]
# <p dir="rtl">
# برنامه ای بنویسید که مقدار ماکزیمم و مینیمم value های دیکشنری را خروجی دهد.

# %%
orange = {'red':255, 'green':165 , 'blue':0}
num= []
for i in orange:
    num.append(orange[i])
print(max(num))
print(min(num))

# %%
min(d.values()),max(d.values())
# Out:
# (1, 10)

# %% [markdown]
# <p dir="rtl">    برنامه ای بنویسید که یک جمله گرفته و تعداد تکرار هر کلمه را در یک دیکشنری ذخیره کند.

# %%
clip = '''CLIP is short for Contrastive Language-Image Pretraining. CLIP is an advance AI model that is jointly developed by OpenAI and UC Berkeley. The model is capable of understanding both textual descriptions and images, leveraging a training approach that emphasizes contrasting pairs of images and text. In this article, we are going to explore the fundamentals and working for CLIP. We are also going to explore its applications.

'''
result = {}
clip= clip.split(" ")
for i in clip:
    result.setdefault(i,0)
    if i in result:
        result[i]+=1
print(result)
# Out:
# {'CLIP': 2, 'is': 4, 'short': 1, 'for': 2, 'Contrastive': 1, 'Language-Image': 1, 'Pretraining.': 1, 'an': 1, 'advance': 1, 'AI': 1, 'model': 2, 'that': 2, 'jointly': 1, 'developed': 1, 'by': 1, 'OpenAI': 1, 'and': 4, 'UC': 1, 'Berkeley.': 1, 'The': 1, 'capable': 1, 'of': 2, 'understanding': 1, 'both': 1, 'textual': 1, 'descriptions': 1, 'images,': 1, 'leveraging': 1, 'a': 1, 'training': 1, 'approach': 1, 'emphasizes': 1, 'contrasting': 1, 'pairs': 1, 'images': 1, 'text.': 1, 'In': 1, 'this': 1, 'article,': 1, 'we': 1, 'are': 2, 'going': 2, 'to': 2, 'explore': 2, 'the': 1, 'fundamentals': 1, 'working': 1, 'CLIP.': 1, 'We': 1, 'also': 1, 'its': 1, 'applications.\n\n': 1}

# %%
clip = '''CLIP is short for Contrastive Language-Image Pretraining. CLIP is an advance AI model that is jointly developed by OpenAI and UC Berkeley. The model is capable of understanding both textual descriptions and images, leveraging a training approach that emphasizes contrasting pairs of images and text. In this article, we are going to explore the fundamentals and working for CLIP. We are also going to explore its applications.

'''
result = {}
clip= clip.split(" ")
for item in clip:
    result[item]= clip.count(item)
print(result)
# Out:
# {'CLIP': 2, 'is': 4, 'short': 1, 'for': 2, 'Contrastive': 1, 'Language-Image': 1, 'Pretraining.': 1, 'an': 1, 'advance': 1, 'AI': 1, 'model': 2, 'that': 2, 'jointly': 1, 'developed': 1, 'by': 1, 'OpenAI': 1, 'and': 4, 'UC': 1, 'Berkeley.': 1, 'The': 1, 'capable': 1, 'of': 2, 'understanding': 1, 'both': 1, 'textual': 1, 'descriptions': 1, 'images,': 1, 'leveraging': 1, 'a': 1, 'training': 1, 'approach': 1, 'emphasizes': 1, 'contrasting': 1, 'pairs': 1, 'images': 1, 'text.': 1, 'In': 1, 'this': 1, 'article,': 1, 'we': 1, 'are': 2, 'going': 2, 'to': 2, 'explore': 2, 'the': 1, 'fundamentals': 1, 'working': 1, 'CLIP.': 1, 'We': 1, 'also': 1, 'its': 1, 'applications.\n\n': 1}
