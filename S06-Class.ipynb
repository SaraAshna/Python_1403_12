# %% [markdown]
# Installing git
# cmd> git >if installed> choosing a folder>cmd >git status>then git add file
# git add: will bring file to stage
# git commit -m 'txt' this txt is shown on github repository
# only the staged files can be commited (so, we should git add before starting commit)
# when add file: one copy of the file will be created in the hidden git flder

# %%
size = { 's':1,
        'm':2,
        'l':3,
        'xl':4}

# %%
size
# Out:
# {'s': 1, 'm': 2, 'l': 3, 'xl': 4}

# %%
for i in size:
    print (i)
# Out:
# s
# m
# l
# xl
