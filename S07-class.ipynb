# %%
name = 'sara'
c = 0
for _ in name:
    c +=1
print(c)
# Out:
# 4

# %% [markdown]
# ### Python Functions
# - A function is a block of code which only runs when it is called.
#
# - You can pass data, known as parameters, into a function.
#
# - A function can return data as a result.

# %% [markdown]
# ### Arguments
# Information can be passed into functions as arguments.
#
# Arguments are specified after the function name, inside the parentheses. You can add as many arguments as you want, just separate them with a comma.
#
# The following example has a function with one argument (fname). When the function is called, we pass along a first name, which is used inside the function to print the full name:
#
# *Arguments are often shortened to args in Python documentations.

# %%
def my_len(s):
    c = 0
    for i in s:
        c+=1
    print(c)

# %%
my_len([5,7,"i"])
# Out:
# 3

# %% [markdown]
# **Diffrence between len Python defualt and our defined len:**
# my_len will show the output but in the default len the result will not print unless using print

# %%
a = len ([5,7,"i"])
a
# Out:
# 3

# %%
b = my_len([5,7,"i"])
# Out:
# 3

# %%
b

# %%
type(b)
# Out:
# NoneType

# %%
def my_len(s):
    c = 0
    for i in s:
        c+=1
    return c

# %% [markdown]
# return >>> saving output
#
# print >>> showing result

# %%
b = my_len([5,7,"i"])
b
# Out:
# 3

# %%
b
# Out:
# 3

# %%
my_len()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 my_len()
#
# TypeError: my_len() missing 1 required positional argument: 's'

# %%
b = [4,8,[5,7],9,[12,48,36],'sara']
len(b)
# Out:
# 6

# %%
b = [4,8,[5,7],9,[12,48,36], 'sara']
def deep_len(value):
    c=0
    for item in value:
        if type(item) == str or type(item)== list:
            c += len(item)
        else:
            c +=1
    return(c)

# %%
deep_len(b)
# Out:
# 12

# %%
b = [4,8,[5,7],9,[12,48,36], 'sara']
def deep_len(value):
    c=0
    for item in value:
        if isinstance(item,str) or isinstance(item, list): #if type(item) == str or type(item)== list:
            c += len(item)
        else:
            c +=1
    return(c) 
#in functions, after return the codes will not execute
# return must be out of for, otherwise it just returns function just once

# %%
deep_len(b)
# Out:
# 12

# %%
def is_even(s):
    if s%2 == 0:
        return True
    else:
        return False

# %%
is_even(9)
# Out:
# False

# %%
def iss_even(s):
    if s%2 == 0:
        print("true")
    else:
        print("false")

# %%
iss_even(7)
# Out:
# false

# %% [markdown]
# **!!!checking the differnce between return and result!!!**
